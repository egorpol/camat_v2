# %%
# Imports
from IPython.display import display

from camat.parser_registry import parse_files

# Backend selection ('music21' | 'partitura')
PARSING_BACKEND = 'partitura'

# Optional: auto summary via parser_registry.parse_files(..., print_parsed_summary=...)
# False disables it; a dict forwards kwargs to parser_utils.print_parsed_summary.
PRINT_PARSED_SUMMARY = True

# ---------------------------------------------------------------------
# Parameter section used in this notebook
# ---------------------------------------------------------------------
FILTER_ZERO_DURATION = True          # filter out notes with duration 0 (grace notes)
ADJUST_FRACTIONAL_DURATION = True    # rounds Duration, Local Onset, and Global Onset to 3 decimals
PARSE_ENHARMONIC = True              # add 'Pitch Enharmonic' column grounded in source notation
DEDUPE_WEAKER_TEXT_EVENTS = False    # drops weaker duplicate text-like events when an anchored copy also exists

PLOTTING_BACKEND = 'bokeh'           # 'plt' | 'bokeh' | 'none'
SHOW_MEASURE_LINES = False            # draw vertical measure lines at measure starts
MEASURE_LINE_COLOR = 'black'         # color for measure lines
SHOW_HOVER = True                    # enable hover tool (Bokeh only)
HOVER_FIELDS = [
    'measure', 'local_onset', 'global_onset', 'duration',
    'pitch', 'pitch_enharmonic', 'midi', 'voice', 'xml_id'
]

DISPLAY_PREVIEW_DF_PITCH = True      # show preview for parsed pitch dataframe
DISPLAY_PREVIEW_DF_EVENTS = True     # show preview for parsed event dataframe
PREVIEW_ROWS = 20                    # number of rows to show in preview
CLEANUP_REMOTE = True                # if source is a URL, delete temp file after parsing
RETURN_PLOTS = False                 # include plot objects in results under 'plot'
PLOT_SIZE_X = 900                    # plot width in pixels
PLOT_SIZE_Y = 600                    # plot height in pixels
ZOOM_DRAG_DIM = 'both'               # 'both' | 'width' | 'height' (Bokeh only)
ZOOM_WHEEL_DIM = 'width'             # 'both' | 'width' | 'height' (Bokeh only)
SHOW_PROGRESS = True                 # tqdm progress bar for multiple files
PROGRESS_DESC = None                 # custom progress label, or None

# Cross-backend options
STRIP_TIES = True                    # music21 backend only
ALIGN_ACCIDENT_SCHEMA = True         # harmonize accidental schema across backends
COLORIZE_VOICES = True               # color-code notes by voice/part in piano roll
PALETTE = 'Category20'               # e.g. 'Category10', 'Category20', 'Set3', or list of colors
INCLUDE_XML_IDS = True               # for MEI, include xml:id as 'xml_id'

# MEI / parser fallback handling
TRY_VEROVIO_MEI_CONVERSION = True        # retry unsupported MEI structures via Verovio conversion
PLOT_PARSED_BARLINES_WITH_VOICE_COLORING = True  # overlay parsed MEI barlines using voice-matched colors
ALLOW_MUSIC21_FALLBACK = False           # strict partitura flow when False; no music21 fallback

# List of file sources (URLs or local paths)
FILE_SOURCES = [
    # 'https://analyse.hfm-weimar.de/database/02/PrJode_Jos0302_COM_1-5_MissaDapac_002_00006.xml',
    # 'https://raw.githubusercontent.com/humdrum-tools/bach-wtc-fugues/refs/heads/master/kern/wtc1f04.krn',
    # 'https://raw.githubusercontent.com/humdrum-tools/bach-wtc/refs/heads/main/kern/wtc1f22.krn',
    #  'https://raw.githubusercontent.com/trompamusic-encodings/Beethoven_Op31_No3_HenleUrtext/refs/heads/master/Beethoven_Op31_No3_3-HenleUrtext.mei',
    #  'https://raw.githubusercontent.com/piasteuck/winterreise-analysis/refs/heads/main/Schubert_Winterreise_Dataset_v2-0/01_RawData/score_musicxml/Schubert_D911-20.xml',
    #  'https://raw.githubusercontent.com/music-encoding/sample-encodings/main/MEI_5.0/Music/Complete_examples/Bach-JS_Ein_feste_Burg.mei',
    #  'https://raw.githubusercontent.com/annplaksin/mei-sample-encodings/refs/heads/main/Dufay-SalveRegina/SalveReginaMisericordiae_Dufay_MEI_Mensural.mei',
    'https://raw.githubusercontent.com/music-encoding/sample-encodings/main/MEI_3.0/Music/Complete_examples/Mozart_Fuge_G_minor.mei',
]

# Parse and visualize
results, dfs_by_name, df_processed = parse_files(
    FILE_SOURCES,
    parsing_backend=PARSING_BACKEND,
    dedupe_weaker_text_events=DEDUPE_WEAKER_TEXT_EVENTS,
    print_parsed_summary=PRINT_PARSED_SUMMARY,
    filter_zero_duration=FILTER_ZERO_DURATION,
    adjust_fractional_duration=ADJUST_FRACTIONAL_DURATION,
    parse_enharmonic=PARSE_ENHARMONIC,
    backend=PLOTTING_BACKEND,
    show_measure_lines=SHOW_MEASURE_LINES,
    measure_line_color=MEASURE_LINE_COLOR,
    show_hover=SHOW_HOVER,
    hover_fields=HOVER_FIELDS,
    display_preview_df_pitch=DISPLAY_PREVIEW_DF_PITCH,
    display_preview_df_events=DISPLAY_PREVIEW_DF_EVENTS,
    preview_rows=PREVIEW_ROWS,
    cleanup_remote=CLEANUP_REMOTE,
    return_plots=RETURN_PLOTS,
    plot_width=PLOT_SIZE_X,
    plot_height=PLOT_SIZE_Y,
    zoom_drag_dim=ZOOM_DRAG_DIM,
    zoom_wheel_dim=ZOOM_WHEEL_DIM,
    show_progress=SHOW_PROGRESS,
    progress_desc=PROGRESS_DESC,
    strip_ties=STRIP_TIES,
    align_accident_schema=ALIGN_ACCIDENT_SCHEMA,
    colorize_voices=COLORIZE_VOICES,
    palette=PALETTE,
    include_xml_ids=INCLUDE_XML_IDS,
    try_verovio_mei_conversion=TRY_VEROVIO_MEI_CONVERSION,
    plot_parsed_barlines_with_voice_coloring=PLOT_PARSED_BARLINES_WITH_VOICE_COLORING,
    allow_music21_fallback=ALLOW_MUSIC21_FALLBACK,
)
# Out:
# Processing (partitura): Mozart_Fuge_G_minor.mei -> 00_mozart_fuge_g_minor
# Detected common-notation MEI. Skipping mensural duration/meter preprocessing.
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported data.FONTSIZE '12'
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] Unsupported '<staffDef>' within <section>
# [Warning] tie with @xml:id horm2ed has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id w18gmx0m has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id n1fgd10m has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id dc0sdct has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id g1gkwdkd has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id y13ghnpg has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id x95iteb has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id yhjkl2r has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id l2yir5g has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id z14x448u has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id a178kxpi has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id t1np0yr0 has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id q3bnuhn has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id f1uc6hfy has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id pobta4s has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id pmt4en1 has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id k3ppxuj has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id m7wng62 has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id iujf4yj has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id l1a0anib has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id m1yzmgv0 has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id r5f1pko has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id h1eybzvy has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id u1754f4a has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id ut2gg0t has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id j1kvbpqh has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id l1bkck2r has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id m4qship has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id pp7bznd has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id q8cupnx has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] trill with @xml:id irpe27h has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id h15z5rsh has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id e17rgq8g has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id v8w4bty has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id cf79cjs has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id kv6wb10 has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id g10i7krp has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id hzm7cch has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id y2ret6z has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id q1lcfwlt has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id z71j0hb has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id u1x5tecu has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id mcfe2zw has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id ni51c3y has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id n6g36tu has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] Cannot parse JSON std::string. Using default options.
# /home/eggi/.conda/envs/py310/lib/python3.10/site-packages/partitura/io/importmei.py:256: UserWarning: The key signature is not encoded in None or in any ancestor scoreDef.
#   warnings.warn(
# /home/eggi/.conda/envs/py310/lib/python3.10/site-packages/partitura/io/importmei.py:259: UserWarning: A default key signature of C maj is set.
#   warnings.warn("A default key signature of C maj is set.")
# /home/eggi/.conda/envs/py310/lib/python3.10/site-packages/partitura/io/importmei.py:1111: UserWarning: Warning : parts have measures of different duration in measure d1e26710
#   warnings.warn(
# Extracted non-barline MEI events: 49 event(s), types=['direction', 'fermata', 'tie'].
#   <div id="cb73edf2-ce30-4674-82ee-ab7876c4682b" data-root-id="p1094" style="display: contents;"></div>
#     Measure  Local Onset  Global Onset  Duration Pitch Pitch Enharmonic  MIDI  \
# 0         1         0.00          0.00      2.00    D5               D5    74
# 1         1         2.00          2.00      1.50   A#4              Bb4    70
# 2         1         3.50          3.50      0.25    A4               A4    69
# 3         1         3.75          3.75      0.25    G4               G4    67
# 4         1         4.00          4.00      0.50   F#4              F#4    66
# 5         1         4.50          4.50      0.50    G4               G4    67
# 6         1         5.00          5.00      1.50    A4               A4    69
# 7         1         6.50          6.50      0.50   D#5              Eb5    75
# 8         1         7.00          7.00      0.50    D5               D5    74
# 9         1         7.50          7.50      0.50    C5               C5    72
# 10        1         8.00          8.00      0.50   A#4              Bb4    70
# 11        1         8.00          8.00      2.00    G4               G4    67
# 12        1         8.50          8.50      0.50    A4               A4    69
# 13        1         9.00          9.00      0.50   A#4              Bb4    70
# 14        1         9.50          9.50      0.50    C5               C5    72
# 15        1        10.00         10.00      1.50    F4               F4    65
# 16        1        10.00         10.00      0.50    D5               D5    74
# 17        1        10.50         10.50      0.50    A4               A4    69
# 18        1        11.00         11.00      1.00    D5               D5    74
# 19        1        11.50         11.50      0.25    E4               E4    64
#
#            Voice  xml_id
# 0   P1 - Voice 1  d1e242
# 1   P1 - Voice 1  d1e256
# 2   P1 - Voice 1  d1e273
# 3   P1 - Voice 1  d1e291
# 4   P1 - Voice 1  d1e391
# 5   P1 - Voice 1  d1e411
# 6   P1 - Voice 1  d1e427
# 7   P1 - Voice 1  d1e442
# 8   P1 - Voice 1  d1e460
# 9   P1 - Voice 1  d1e476
# 10  P1 - Voice 1  d1e515
# 11  P2 - Voice 1  d1e630
# 12  P1 - Voice 1  d1e533
# 13  P1 - Voice 1  d1e549
# 14  P1 - Voice 1  d1e567
# 15  P2 - Voice 1  d1e644
# 16  P1 - Voice 1  d1e583
# 17  P1 - Voice 1  d1e599
# 18  P1 - Voice 1  d1e615
# 19  P2 - Voice 1  d1e659
# Rows: 1523, unique pitches: 43
#    type subtype  Measure  Local Onset  Global Onset  Duration         Voice  \
# 0   tie    <NA>        5          0.0          16.0       0.0  P1 - Voice 1
# 1   tie    <NA>        8          3.0          31.0       0.0  P3 - Voice 1
# 2   tie    <NA>       11          3.0          43.0       0.0  P3 - Voice 1
# 3   tie    <NA>       12          2.0          46.0       0.0  P2 - Voice 1
# 4   tie    <NA>       14          3.0          55.0       0.0  P1 - Voice 1
# 5   tie    <NA>       15          2.0          58.0       0.0  P3 - Voice 1
# 6   tie    <NA>       16          3.0          63.0       0.0  P3 - Voice 1
# 7   tie    <NA>       16          3.0          63.0       0.0  P4 - Voice 1
# 8   tie    <NA>       18          3.0          71.0       0.0  P2 - Voice 1
# 9   tie    <NA>       20          3.0          79.0       0.0  P2 - Voice 1
# 10  tie    <NA>       20          3.0          79.0       0.0  P3 - Voice 1
# 11  tie    <NA>       21          3.0          83.0       0.0  P2 - Voice 1
# 12  tie    <NA>       30          3.0         119.0       0.0  P2 - Voice 1
# 13  tie    <NA>       32          2.0         126.0       0.0  P3 - Voice 1
# 14  tie    <NA>       36          3.0         143.0       0.0  P3 - Voice 1
# 15  tie    <NA>       44          3.0         175.0       0.0  P2 - Voice 1
# 16  tie    <NA>       48          3.0         191.0       0.0  P4 - Voice 1
# 17  tie    <NA>       51          3.0         203.0       0.0  P3 - Voice 1
# 18  tie    <NA>       52          3.0         207.0       0.0  P1 - Voice 1
# 19  tie    <NA>       54          3.0         215.0       0.0  P3 - Voice 1
#
#    xml_id start_xml_id end_xml_id  ... plist tstamp_raw tstamp2_raw verse_n  \
# 0    <NA>       d1e887     d1e904  ...  <NA>          1        <NA>    <NA>
# 1    <NA>      d1e2020    d1e2271  ...  <NA>          4        <NA>    <NA>
# 2    <NA>      d1e2837    d1e2975  ...  <NA>          4        <NA>    <NA>
# 3    <NA>      d1e2955    d1e2975  ...  <NA>      1.083        <NA>    <NA>
# 4    <NA>      d1e3407    d1e3643  ...  <NA>          4        <NA>    <NA>
# 5    <NA>      d1e3861    d1e4019  ...  <NA>          3        <NA>    <NA>
# 6    <NA>      d1e4111    d1e4338  ...  <NA>          4        <NA>    <NA>
# 7    <NA>      d1e4218    d1e4460  ...  <NA>          4        <NA>    <NA>
# 8    <NA>      d1e4744    d1e4927  ...  <NA>          4        <NA>    <NA>
# 9    <NA>      d1e5301    d1e5509  ...  <NA>          4        <NA>    <NA>
# 10   <NA>      d1e5412    d1e5630  ...  <NA>          4        <NA>    <NA>
# 11   <NA>      d1e5612    d1e5780  ...  <NA>          4        <NA>    <NA>
# 12   <NA>      d1e8063    d1e8315  ...  <NA>          4        <NA>    <NA>
# 13   <NA>      d1e8705    d1e8938  ...  <NA>          3        <NA>    <NA>
# 14   <NA>      d1e9755    d1e9990  ...  <NA>          4        <NA>    <NA>
# 15   <NA>     d1e11739   d1e11927  ...  <NA>          4        <NA>    <NA>
# 16   <NA>     d1e12730   d1e12974  ...  <NA>          4        <NA>    <NA>
# 17   <NA>     d1e13543   d1e13774  ...  <NA>          4        <NA>    <NA>
# 18   <NA>     d1e13656   d1e13903  ...  <NA>          4        <NA>    <NA>
# 19   <NA>     d1e14542   d1e14873  ...  <NA>          4        <NA>    <NA>
#
#    wordpos   con    mm mm_unit mm_dots extra
# 0     <NA>  <NA>  <NA>    <NA>    <NA>  <NA>
# 1     <NA>  <NA>  <NA>    <NA>    <NA>  <NA>
# 2     <NA>  <NA>  <NA>    <NA>    <NA>  <NA>
# 3     <NA>  <NA>  <NA>    <NA>    <NA>  <NA>
# 4     <NA>  <NA>  <NA>    <NA>    <NA>  <NA>
# 5     <NA>  <NA>  <NA>    <NA>    <NA>  <NA>
# 6     <NA>  <NA>  <NA>    <NA>    <NA>  <NA>
# 7     <NA>  <NA>  <NA>    <NA>    <NA>  <NA>
# 8     <NA>  <NA>  <NA>    <NA>    <NA>  <NA>
# 9     <NA>  <NA>  <NA>    <NA>    <NA>  <NA>
# 10    <NA>  <NA>  <NA>    <NA>    <NA>  <NA>
# 11    <NA>  <NA>  <NA>    <NA>    <NA>  <NA>
# 12    <NA>  <NA>  <NA>    <NA>    <NA>  <NA>
# 13    <NA>  <NA>  <NA>    <NA>    <NA>  <NA>
# 14    <NA>  <NA>  <NA>    <NA>    <NA>  <NA>
# 15    <NA>  <NA>  <NA>    <NA>    <NA>  <NA>
# 16    <NA>  <NA>  <NA>    <NA>    <NA>  <NA>
# 17    <NA>  <NA>  <NA>    <NA>    <NA>  <NA>
# 18    <NA>  <NA>  <NA>    <NA>    <NA>  <NA>
# 19    <NA>  <NA>  <NA>    <NA>    <NA>  <NA>
#
# [20 rows x 30 columns]
# Event rows: 49
#
# Parsed DataFrames:
# - 00_mozart_fuge_g_minor: rows=1523, unique_pitches=43, min_duration=0.25, voices=4 (['P1 - Voice 1', 'P2 - Voice 1', 'P3 - Voice 1', 'P4 - Voice 1'])

# %%
list(dfs_by_name)
# Out:
# ['00_mozart_fuge_g_minor_pitch', '00_mozart_fuge_g_minor_events']

# %%
display(dfs_by_name["00_bach_js_ein_feste_burg_events"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 display(dfs_by_name["00_bach_js_ein_feste_burg_events"])
#
# KeyError: '00_bach_js_ein_feste_burg_events'

# %%
# filter lyric events

import pandas as pd

df = dfs_by_name["00_bach_js_ein_feste_burg_events"]

with pd.option_context('display.max_rows', None,
                       'display.max_columns', None,
                       'display.max_colwidth', None):
    display(df[df["type"] == "lyric"][["Global Onset", "text", "verse_n", "start_xml_id"]])
# Out:
#     Global Onset    text verse_n start_xml_id
# 0           -1.0    Ein´       1        d1e64
# 1           -1.0      Er       2        d1e64
# 2            0.0      fe       1       d1e366
# 3            0.0   hilft       2       d1e366
# 4            1.0     ste       1       d1e390
# 5            1.0     uns       2       d1e390
# 6            2.0    Burg       1       d1e414
# 7            2.0    frei       2       d1e414
# 8            3.0     ist       1       d1e458
# 9            3.0     aus       2       d1e458
# 10           4.0      un       1       d1e565
# 11           4.0      al       2       d1e565
# 12           5.0     ser       1       d1e619
# 13           5.0     ler       2       d1e619
# 14           6.0   Gott,       1       d1e647
# 15           6.0    Not,       2       d1e647
# 18           7.0     die       2       d1e673
# 19           7.0    ein'       1       d1e673
# 20           8.0      gu       1       d1e835
# 21           8.0     uns       2       d1e835
# 22           9.0      te       1       d1e861
# 23           9.0   jetzt       2       d1e861
# 24          10.0    Wehr       1       d1e889
# 25          10.0     hat       2       d1e889
# 26          11.0     und       1       d1e913
# 27          11.0      be       2       d1e913
# 28          12.0     Waf       1      d1e1158
# 29          12.0    trof       2      d1e1158
# 33          14.0    fen.       1      d1e1237
# 34          14.0    fen.       2      d1e1237
# 37          15.0     Der       1      d1e1523
# 38          16.0    alt'       1      d1e1744
# 43          18.0      bö       1      d1e1782
# 44          19.0      se       1      d1e1801
# 47          20.0  Feind,       1      d1e2052
# 48          22.0     mit       1      d1e2073
# 49          23.0   Ernst       1      d1e2092
# 50          24.0    er's       1      d1e2261
# 51          25.0   jetzt       1      d1e2280
# 53          26.0  meint,       1      d1e2301
# 55          27.0   groß'       1      d1e2322
# 56          28.0   Macht       1      d1e2640
# 57          28.5     und       1      d1e2659
# 58          29.0    viel       1      d1e2680
# 61          30.0    List       1      d1e2699
# 62          31.0    sein       1      d1e2720
# 63          32.0    grau       1      d1e2986
# 64          33.0     sam       1      d1e3005
# 65          34.0    Rüst       1      d1e3024
# 66          35.0    zeug       1      d1e3066
# 67          36.0    ist,       1      d1e3293
# 70          37.0     auf       1      d1e3316
# 71          38.0   Erd'n       1      d1e3337
# 72          39.0     ist       1      d1e3358
# 73          40.0   nicht       1      d1e3693
# 74          41.0  sein´s       1      d1e3712
# 75          42.0    Glei       1      d1e3750
# 81          46.0   chen.       1      d1e4088
# 83           NaN    Ein´       1         <NA>
# 84           NaN      Er       2         <NA>
# 85           NaN      fe       1         <NA>
# 86           NaN   hilft       2         <NA>
# 87           NaN     ste       1         <NA>
# 88           NaN     uns       2         <NA>
# 89           NaN    Burg       1         <NA>
# 90           NaN    frei       2         <NA>
# 91           NaN     ist       1         <NA>
# 92           NaN     aus       2         <NA>

# %%
url = FILE_SOURCES[0]

from camat import (
    vrv_set_options, vrv_load_from_url, vrv_load_from_file,
    vrv_render_page, vrv_display_svg, vrv_debug_info
)
vrv_set_options(pageWidth=12000, pageHeight=1200, scale=40, breaks="none", removeIds=False, xmlIdSeed=0)

# Loading does not auto-render; explicitly render/display after load.
if isinstance(url, str) and url.startswith(("http://", "https://")):
    pages = vrv_load_from_url(url)
else:
    pages = vrv_load_from_file(url)

print(f"Verovio loaded pages: {pages}")
if pages > 0:
    svg = vrv_render_page(1)
    vrv_display_svg(svg)
else:
    print("No pages rendered. Debug info:", vrv_debug_info())
# Out:
# [Warning] Element <title> within <pgHead> is not supported and will be ignored
# [Warning] Element <seg> within <pgHead> is not supported and will be ignored
# [Warning] Element <seg> within <pgHead> is not supported and will be ignored
# [Warning] slur 'io6f4g2' is not encoded in the measure of its start 'd1e1908'. This may cause improper rendering.
# [Warning] slur 'u6mwdhu' is not encoded in the measure of its start 'd1e2429'. This may cause improper rendering.
# [Warning] slur 'vk1q7gh' is not encoded in the measure of its start 'd1e2536'. This may cause improper rendering.
# [Warning] 1 time pointing element(s) could not be matched in measure d1e3291
# [Warning] 1 time pointing element(s) could not be matched in measure d1e2973
# [Warning] 1 time pointing element(s) could not be matched in measure d1e2638
# [Warning] 1 time pointing element(s) could not be matched in measure d1e1742
# [Warning] slur with @xml:id b1osylqj has both a @endid and an @tstamp2; @tstamp2 is ignored
# [Warning] slur with @xml:id b1osylqj has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] slur with @xml:id c1v7hphf has both a @endid and an @tstamp2; @tstamp2 is ignored
# [Warning] slur with @xml:id c1v7hphf has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] slur with @xml:id f1dyw6pz has both a @endid and an @tstamp2; @tstamp2 is ignored
# [Warning] slur with @xml:id f1dyw6pz has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] slur with @xml:id g1m0s9yz has both a @endid and an @tstamp2; @tstamp2 is ignored
# [Warning] slur with @xml:id g1m0s9yz has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] slur with @xml:id io6f4g2 has both a @endid and an @tstamp2; @tstamp2 is ignored
# [Warning] slur with @xml:id io6f4g2 has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] slur with @xml:id u6mwdhu has both a @endid and an @tstamp2; @tstamp2 is ignored
# [Warning] slur with @xml:id u6mwdhu has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] slur with @xml:id vk1q7gh has both a @endid and an @tstamp2; @tstamp2 is ignored
# [Warning] slur with @xml:id vk1q7gh has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] slur with @xml:id p6gybly has both a @endid and an @tstamp2; @tstamp2 is ignored
# [Warning] slur with @xml:id p6gybly has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] slur with @xml:id q1yl8poa has both a @endid and an @tstamp2; @tstamp2 is ignored
# [Warning] slur with @xml:id q1yl8poa has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] tie with @xml:id r1n533l3 has both a @endid and an @tstamp2; @tstamp2 is ignored
# [Warning] tie with @xml:id r1n533l3 has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] slur with @xml:id s13xt7m8 has both a @startid and an @tstamp; @tstamp is ignored
# [Warning] slur with @xml:id t1amgnm2 has both a @startid and an @tstamp; @tstamp is ignored
# Verovio loaded pages: 1
